# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# train the prediction model using Naive Bayse
corpus = list(pd.read_excel('train_set_2.xlsx')['Segement'].values)
labels_2 = pd.read_excel('train_set_2.xlsx')['Label_2'].values

# learned count vectorizer
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(corpus)

# learned tfidf transformer
transformer = TfidfTransformer()
tfidf = transformer.fit_transform(X)

clf = MultinomialNB()
clf.fit(tfidf, labels_2)

# saving the trained model
filename = 'finalized_NB_model.sav'
pickle.dump(clf, open(filename, 'wb'))

# %%
import pandas as pd
import xlwings as xw
import thulac

# first segement the cleaned posts 
thu1 = thulac.thulac(model_path='./Thulac_models/', user_dict='./user_dict.txt', rm_space=True, seg_only=True, filt=True)

# iterate each day to predict the sentiment
wb = xw.Book('weibo_clean.xls')
shts = wb.sheets
sentiments = [] # {'date': str, 'seg_posts': list, 'prediction': ndarray}
for sht in shts:
    date = sht.name
    print('perform prediction in day: %s' % date)
    posts = sht.range('A1').expand('down').value

    # perform the thulac segementation
    segement_posts_thulac = []
    for post in posts:
        if type(post) == str:
            t1 = thu1.cut(post, text=True) 
            segement_posts_thulac.append(t1)

    # using model to predict
    X = vectorizer.transform(segement_posts_thulac)
    tfidf = transformer.transform(X)
    pred = clf.predict(tfidf)
    rst = {'date': date, 'seg_posts': segement_posts_thulac, 'predictions': pred}
    sentiments.append(rst)

wb.close()
# Out:
# Model loaded succeed
# perform prediction in day: 2019-12-20
# perform prediction in day: 2019-12-21
# perform prediction in day: 2019-12-22
# perform prediction in day: 2019-12-23
# perform prediction in day: 2019-12-24
# perform prediction in day: 2019-12-25
# perform prediction in day: 2019-12-26
# perform prediction in day: 2019-12-27
# perform prediction in day: 2019-12-28
# perform prediction in day: 2019-12-29
# perform prediction in day: 2019-12-30
# perform prediction in day: 2019-12-31
# perform prediction in day: 2020-01-01
# perform prediction in day: 2020-01-02
# perform prediction in day: 2020-01-03
# perform prediction in day: 2020-01-04
# perform prediction in day: 2020-01-05
# perform prediction in day: 2020-01-06
# perform prediction in day: 2020-01-07
# perform prediction in day: 2020-01-08
# perform prediction in day: 2020-01-09
# perform prediction in day: 2020-01-10
# perform prediction in day: 2020-01-11
# perform prediction in day: 2020-01-12
# perform prediction in day: 2020-01-13
# perform prediction in day: 2020-01-14
# perform prediction in day: 2020-01-15
# perform prediction in day: 2020-01-16
# perform prediction in day: 2020-01-17
# perform prediction in day: 2020-01-18
# perform prediction in day: 2020-01-19
# perform prediction in day: 2020-01-20
# perform prediction in day: 2020-01-21
# perform prediction in day: 2020-01-22
# perform prediction in day: 2020-01-23
# perform prediction in day: 2020-01-24
# perform prediction in day: 2020-01-25
# perform prediction in day: 2020-01-26
# perform prediction in day: 2020-01-27
# perform prediction in day: 2020-01-28
# perform prediction in day: 2020-01-29
# perform prediction in day: 2020-01-30
# perform prediction in day: 2020-01-31
# perform prediction in day: 2020-02-01
# perform prediction in day: 2020-02-02
# perform prediction in day: 2020-02-03
# perform prediction in day: 2020-02-04
# perform prediction in day: 2020-02-05
# perform prediction in day: 2020-02-06
# perform prediction in day: 2020-02-07
# perform prediction in day: 2020-02-08
# perform prediction in day: 2020-02-09
# perform prediction in day: 2020-02-10
# perform prediction in day: 2020-02-11
# perform prediction in day: 2020-02-12
# perform prediction in day: 2020-02-13
# perform prediction in day: 2020-02-14
# perform prediction in day: 2020-02-15
# perform prediction in day: 2020-02-16
# perform prediction in day: 2020-02-17
# perform prediction in day: 2020-02-18
# perform prediction in day: 2020-02-19
# perform prediction in day: 2020-02-20
# perform prediction in day: 2020-02-21
# perform prediction in day: 2020-02-22
# perform prediction in day: 2020-02-23
# perform prediction in day: 2020-02-24
# perform prediction in day: 2020-02-25
# perform prediction in day: 2020-02-26
# perform prediction in day: 2020-02-27
# perform prediction in day: 2020-02-28
# perform prediction in day: 2020-02-29
# perform prediction in day: 2020-03-01
# perform prediction in day: 2020-03-02
# perform prediction in day: 2020-03-03
# perform prediction in day: 2020-03-04
# perform prediction in day: 2020-03-05
# perform prediction in day: 2020-03-06
# perform prediction in day: 2020-03-07
# perform prediction in day: 2020-03-08
# perform prediction in day: 2020-03-09
# perform prediction in day: 2020-03-10
# perform prediction in day: 2020-03-11
# perform prediction in day: 2020-03-12
# perform prediction in day: 2020-03-13
# perform prediction in day: 2020-03-14
# perform prediction in day: 2020-03-15
# perform prediction in day: 2020-03-16
# perform prediction in day: 2020-03-17
# perform prediction in day: 2020-03-18
# perform prediction in day: 2020-03-19
# perform prediction in day: 2020-03-20
# perform prediction in day: 2020-03-21
# perform prediction in day: 2020-03-22
# perform prediction in day: 2020-03-23
# perform prediction in day: 2020-03-24
# perform prediction in day: 2020-03-25
# perform prediction in day: 2020-03-26
# perform prediction in day: 2020-03-27
# perform prediction in day: 2020-03-28
# perform prediction in day: 2020-03-29
# perform prediction in day: 2020-03-30
# perform prediction in day: 2020-03-31
# perform prediction in day: 2020-04-01
# perform prediction in day: 2020-04-02
# perform prediction in day: 2020-04-03
# perform prediction in day: 2020-04-04
# perform prediction in day: 2020-04-05
# perform prediction in day: 2020-04-06
# perform prediction in day: 2020-04-07
# perform prediction in day: 2020-04-08
# perform prediction in day: 2020-04-09
# perform prediction in day: 2020-04-10
# perform prediction in day: 2020-04-11
# perform prediction in day: 2020-04-12
# perform prediction in day: 2020-04-13
# perform prediction in day: 2020-04-14
# perform prediction in day: 2020-04-15
# perform prediction in day: 2020-04-16
# perform prediction in day: 2020-04-17
# perform prediction in day: 2020-04-18
# perform prediction in day: 2020-04-19
# perform prediction in day: 2020-04-20
# perform prediction in day: 2020-04-21
# perform prediction in day: 2020-04-22
# perform prediction in day: 2020-04-23
# perform prediction in day: 2020-04-24
# perform prediction in day: 2020-04-25
# perform prediction in day: 2020-04-26
# perform prediction in day: 2020-04-27
# perform prediction in day: 2020-04-28
# perform prediction in day: 2020-04-29
# perform prediction in day: 2020-04-30

# %%
import pickle
import pandas as pd
import xlwings as xw
import thulac
import numpy as np
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

thu1 = thulac.thulac(model_path='./Thulac_models/', user_dict='./user_dict.txt', rm_space=True, seg_only=True, filt=True)

wb = xw.Book('final_test.xlsx')
sht = wb.sheets[0]
posts = sht.range('A1').expand('down').value
labels = sht.range('B1').expand('down').value

segement_posts_thulac = []
for post in posts:
    if type(post) == str:
        t1 = thu1.cut(post, text=True) 
        segement_posts_thulac.append(t1)

X = vectorizer.transform(segement_posts_thulac)
tfidf = transformer.transform(X)
loaded_model = pickle.load(open('finalized_NB_model.sav', 'rb'))
preds = loaded_model.predict(tfidf)
loaded_model.score(tfidf, np.array(labels))
# Out:
# Model loaded succeed
# 0.618

# %%
import pymongo
import collections

client = pymongo.MongoClient("mongodb://Song:a931021@cluster0-shard-00-00-ywxjv.azure.mongodb.net:27017,cluster0-shard-00-01-ywxjv.azure.mongodb.net:27017,cluster0-shard-00-02-ywxjv.azure.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.nCoV_data
collection = db['results']
SA = collection.find({'tag': 'sentiment_analysis'})[0]

d = {}
for each in SA['data']:
    date = each['date']
    pred = each['predictions']
    dict_count = dict(collections.Counter(pred))
    keys = list(dict_count.keys())
    dict_count['-1'] = dict_count[-1].pop if -1 
    dict_count['0'] = dict_count[0].pop
    dict_count['1'] = dict_count[1].pop
    d[str(date)] = dict_count
print(d)
collection.insert_one({'tag': 'prediction_count', 'data': d})
# Out:
# {'2019-12-20': {0: 6, -1: 1}, '2019-12-21': {0: 4, -1: 2}, '2019-12-22': {0: 4, -1: 1}, '2019-12-23': {0: 13, -1: 1}, '2019-12-24': {-1: 2, 0: 7, 1: 1}, '2019-12-25': {0: 6, 1: 2}, '2019-12-26': {0: 3}, '2019-12-27': {0: 5, -1: 1}, '2019-12-28': {0: 3, -1: 1}, '2019-12-29': {0: 4}, '2019-12-30': {0: 5}, '2019-12-31': {0: 143, -1: 6, 1: 2}, '2020-01-01': {0: 36, -1: 2, 1: 3}, '2020-01-02': {0: 12, -1: 1}, '2020-01-03': {0: 18, -1: 1}, '2020-01-04': {0: 19, 1: 1, -1: 2}, '2020-01-05': {0: 27, -1: 7, 1: 1}, '2020-01-06': {0: 31, -1: 2}, '2020-01-07': {0: 9, 1: 1}, '2020-01-08': {0: 12, 1: 1, -1: 1}, '2020-01-09': {0: 1441, -1: 245, 1: 243}, '2020-01-10': {0: 340, -1: 34, 1: 14}, '2020-01-11': {0: 577, -1: 41, 1: 35}, '2020-01-12': {0: 287, -1: 28, 1: 8}, '2020-01-13': {0: 281, -1: 35, 1: 13}, '2020-01-14': {-1: 57, 0: 423, 1: 55}, '2020-01-15': {0: 422, -1: 100, 1: 78}, '2020-01-16': {0: 528, -1: 138, 1: 82}, '2020-01-17': {0: 663, 1: 264, -1: 214}, '2020-01-18': {1: 187, 0: 605, -1: 162}, '2020-01-19': {-1: 202, 0: 807, 1: 269}, '2020-01-20': {0: 848, 1: 239, -1: 167}, '2020-01-21': {1: 471, -1: 246, 0: 623}, '2020-01-22': {0: 641, 1: 433, -1: 278}, '2020-01-23': {-1: 225, 0: 567, 1: 263}, '2020-01-24': {0: 896, 1: 429, -1: 335}, '2020-01-25': {1: 327, 0: 622, -1: 221}, '2020-01-26': {1: 207, 0: 786, -1: 220}, '2020-01-27': {-1: 293, 1: 232, 0: 682}, '2020-01-28': {0: 1481, -1: 514, 1: 390}, '2020-01-29': {0: 843, -1: 323, 1: 229},
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# <ipython-input-55-a4a92d6227a1> in <module>()
#      14     d[str(date)] = dict_count
#      15 print(d)
# ---> 16 collection.insert_one({'tag': 'prediction_count', 'data': d})
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in insert_one(self, document, bypass_document_validation, session)
#     698                          write_concern=write_concern,
#     699                          bypass_doc_val=bypass_document_validation,
# --> 700                          session=session),
#     701             write_concern.acknowledged)
#     702
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     612             return self._insert_one(
#     613                 docs, ordered, check_keys, manipulate, write_concern, op_id,
# --> 614                 bypass_doc_val, session)
#     615
#     616         ids = []
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     600
#     601         self.__database.client._retryable_write(
# --> 602             acknowledged, _insert_command, session)
#     603
#     604         if not isinstance(doc, RawBSONDocument):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/mongo_client.py in _retryable_write(self, retryable, func, session)
#    1278         """Internal retryable write helper."""
#    1279         with self._tmp_session(session) as s:
# -> 1280             return self._retry_with_session(retryable, func, s, None)
#    1281
#    1282     def __reset_server(self, address):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1231                             raise last_error
#    1232                         retryable = False
# -> 1233                     return func(session, sock_info, retryable)
#    1234             except ServerSelectionTimeoutError:
#    1235                 if is_retrying():
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/collection.py in _insert_command(session, sock_info, retryable_write)
#     595                 session=session,
#     596                 client=self.__database.client,
# --> 597                 retryable_write=retryable_write)
#     598
#     599             _check_write_command_response(result)
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields)
#     587         # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     588         except BaseException as error:
# --> 589             self._raise_connection_failure(error)
#     590
#     591     def send_message(self, message, max_doc_size):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in _raise_connection_failure(self, error)
#     748             _raise_connection_failure(self.address, error)
#     749         else:
# --> 750             raise error
#     751
#     752     def __eq__(self, other):
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields)
#     582                            use_op_msg=self.op_msg_enabled,
#     583                            unacknowledged=unacknowledged,
# --> 584                            user_fields=user_fields)
#     585         except OperationFailure:
#     586             raise
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/network.py in command(sock, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields)
#     119         request_id, msg, size, max_doc_size = message._op_msg(
#     120             flags, spec, dbname, read_preference, slave_ok, check_keys,
# --> 121             codec_options, ctx=compression_ctx)
#     122         # If this is an unacknowledged write then make sure the encoded doc(s)
#     123         # are small enough, otherwise rely on the server to return an error.
#
# ~/anaconda3/lib/python3.6/site-packages/pymongo/message.py in _op_msg(flags, command, dbname, read_preference, slave_ok, check_keys, opts, ctx)
#     676                 flags, command, identifier, docs, check_keys, opts, ctx)
#     677         return _op_msg_uncompressed(
# --> 678             flags, command, identifier, docs, check_keys, opts)
#     679     finally:
#     680         # Add the field back to the command.
#
# InvalidDocument: documents must have only string keys, key was 0

# %%
import pymongo
import collections

client = pymongo.MongoClient("mongodb://Song:a931021@cluster0-shard-00-00-ywxjv.azure.mongodb.net:27017,cluster0-shard-00-01-ywxjv.azure.mongodb.net:27017,cluster0-shard-00-02-ywxjv.azure.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.nCoV_data
collection = db['results']

for d in sentiments:
    pred = d['predictions']
    d['day_sentiment'] = np.mean(pred)
    dict_count = dict(collections.Counter(pred))
    
    percent_neg = dict_count[-1] / len(pred) if -1 in list(dict_count.keys()) else 0
    percent_neu = dict_count[0] / len(pred) if 0 in list(dict_count.keys()) else 0
    percent_pos = dict_count[1] / len(pred) if 1 in list(dict_count.keys()) else 0
    d['percentage'] = [percent_neg, percent_neu, percent_pos]
    d.pop('seg_posts')

collection.insert_one({'tag': 'sentiment_result', 'data': sentiments})
